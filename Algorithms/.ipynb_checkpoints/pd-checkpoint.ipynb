# %%
# ?pd.read_csv

# %%
# ?pd.read_table

# %%
d = pd.read_table('./c2_all_type_pd1118.txt', header=None)

# %%
d
# Out:
#                                                        0
# 0         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 1         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 2         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 3         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 4         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 5         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 6         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 7         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 8         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 9         1.0000000e+00   1.0000000e+01   1.0000000e+...
# 10        1.0000000e+00   1.0000000e+01   1.0000000e+...
# 11        1.0000000e+00   1.0000000e+01   1.0000000e+...
# 12        1.0000000e+00   1.0000000e+01   1.0000000e+...
# 13        1.0000000e+00   1.0000000e+01   1.0000000e+...
# 14        1.0000000e+00   1.0000000e+01   1.0000000e+...
# ...
